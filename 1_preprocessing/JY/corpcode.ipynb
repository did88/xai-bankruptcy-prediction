# %%
import requests
import os

# DART API KEY 입력
api_key = os.getenv("DART_API_KEY")

# 요청 URL
url = f"https://opendart.fss.or.kr/api/corpCode.xml?crtfc_key={api_key}"

# 파일 다운로드
response = requests.get(url)
with open("corpCode.zip", "wb") as f:
    f.write(response.content)

print("corpCode.zip 파일이 저장되었습니다.")

import zipfile

# corpCode.zip 파일에서 CORPCODE.xml 추출
with zipfile.ZipFile("corpCode.zip", "r") as zip_ref:
    zip_ref.extract("CORPCODE.xml")

print("CORPCODE.xml 파일이 추출되었습니다.")

# %%
import pandas as pd

corpcode = pd.read_xml("CORPCODE.xml")
corpcode.head()
# Out:
#    corp_code          corp_name  \
# 0     434003                 다코
# 1     430964              굿앤엘에스
# 2     388953  크레디피아제이십오차유동화전문회사
# 3     179984             연방건설산업
# 4     420143     브룩스피알아이오토메이션잉크
#
#                                        corp_eng_name stock_code  modify_date
# 0                                   Daco corporation                20170630
# 1                                 Good & LS Co.,Ltd.                20170630
# 2  Credipia 25th Asset Securitization Specialty L...                20170630
# 3                                           youn bao                20170630
# 4                        BROOKS-PRI Automation, Inc.                20170630

# %%
corpcode['stock_code'].unique()
# Out:
# array([' ', '036720', '040130', ..., '232830', '136150', '476040'],
#       shape=(3872,), dtype=object)

# %%
stock_company = corpcode.loc[corpcode['stock_code'] != ' '].copy()
stock_company.head()
# Out:
#       corp_code corp_name                              corp_eng_name  \
# 1946     260985      한빛네트                            HanbitNet, Inc.
# 1958     264529      엔플렉스                                 Nplex,Inc.
# 1959     358545    동서정보기술  Dong Seo Information Technology Co., Ltd.
# 2699     231567     애드모바일
# 3771     359614       리더컴                        LEADER COMM.Co.,Ltd
#
#      stock_code  modify_date
# 1946     036720     20170630
# 1958     040130     20170630
# 1959     055000     20170630
# 2699     032600     20170630
# 3771     056140     20170630

# %%
import pandas as pd
폐지 = pd.read_csv("tsnull.csv", dtype={'거래소코드':str})
폐지.head(1)
# Out:
#    Unnamed: 0      회사명    거래소코드     회계년도  자산(*)(IFRS)(천원)  비유동자산(*)(IFRS)(천원)  \
# 0          81  (주)가온칩스  399720   2018/12              NaN                 NaN
#
#    유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 0                NaN              NaN               NaN
#
#    이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출액(수익)(*)(IFRS)(천원)  매출총이익(손실)(IFRS)(천원)  \
# 0                      NaN  ...                   NaN                  NaN
#
#    판매비와 관리비(물류원가 등 포함)(*)(IFRS)(천원)  * (정상)영업손익(보고서기재)(IFRS)(천원)  \
# 0                               NaN                          NaN
#
#    매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  \
# 0                NaN                  NaN                NaN             NaN
#
#    매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일
# 0                         NaN    NaN
#
# [1 rows x 29 columns]

# %%
폐지 = 폐지.rename(columns={'거래소코드': 'stock_code'})
폐지['stock_code'] = 폐지['stock_code'].astype(str).str.strip().str.zfill(6)
stock_company['stock_code'] = stock_company['stock_code'].astype(str).str.strip().str.zfill(6)
merged_df = 폐지.merge(stock_company, on='stock_code', how='left')
merged_df.head()
# Out:
#    Unnamed: 0       회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 0          81   (주)가온칩스     399720  2018/12              NaN
# 1          82   (주)가온칩스     399720  2019/12              NaN
# 2          87  (주)강동씨앤엘     198440  2014/12              NaN
# 3          88  (주)강동씨앤엘     198440  2015/12              NaN
# 4          89  (주)강동씨앤엘     198440  2016/12              NaN
#
#    비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 0                 NaN                NaN              NaN               NaN
# 1                 NaN                NaN              NaN               NaN
# 2                 NaN                NaN              NaN               NaN
# 3                 NaN                NaN              NaN               NaN
# 4                 NaN                NaN              NaN               NaN
#
#    이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 0                      NaN  ...                NaN                  NaN
# 1                      NaN  ...                NaN                  NaN
# 2                      NaN  ...                NaN                  NaN
# 3                      NaN  ...                NaN                  NaN
# 4                      NaN  ...                NaN                  NaN
#
#    재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 0                NaN             NaN                         NaN    NaN
# 1                NaN             NaN                         NaN    NaN
# 2                NaN             NaN                         NaN    NaN
# 3                NaN             NaN                         NaN    NaN
# 4                NaN             NaN                         NaN    NaN
#
#    corp_code  corp_name          corp_eng_name  modify_date
# 0    1364747       가온칩스    GAONCHIPS CO., LTD.     20230216
# 1    1364747       가온칩스    GAONCHIPS CO., LTD.     20230216
# 2    1032583      강동씨앤엘  KANGDONG C&L co., Ltd     20250327
# 3    1032583      강동씨앤엘  KANGDONG C&L co., Ltd     20250327
# 4    1032583      강동씨앤엘  KANGDONG C&L co., Ltd     20250327
#
# [5 rows x 33 columns]

# %%
null_df = merged_df.loc[merged_df.isnull().mean(axis=1) > 0.1]
null_df.head(1)
# Out:
#    Unnamed: 0       회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 0         238  (주)골프존데카     183410  2014/12              NaN
#
#    비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 0                 NaN                NaN              NaN               NaN
#
#    이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 0                      NaN  ...                NaN                  NaN
#
#    재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)       상장폐지일  \
# 0                NaN             NaN                         NaN  2024/02/22
#
#    corp_code  corp_name          corp_eng_name  modify_date
# 0     764807    골프존클라우드  GolfzonCloud Co.,Ltd.     20250227
#
# [1 rows x 33 columns]

# %%
null_df.tail()
# Out:
#       Unnamed: 0            회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 1751       21892  케이만금세기차륜집단(유)     900280  2022/12              NaN
# 1752       21893  케이만금세기차륜집단(유)     900280  2023/12              NaN
# 1804       22576       패션플랫폼(주)     256090  2014/12              NaN
# 1805       22577       패션플랫폼(주)     256090  2015/12              NaN
# 1807       22637     평산차업집단유한공사     950010  2014/12              NaN
#
#       비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  \
# 1751                 NaN                NaN              NaN
# 1752                 NaN                NaN              NaN
# 1804                 NaN                NaN              NaN
# 1805                 NaN                NaN              NaN
# 1807                 NaN                NaN              NaN
#
#       자본금(*)(IFRS)(천원)  이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  \
# 1751               NaN                      NaN  ...                NaN
# 1752               NaN                      NaN  ...                NaN
# 1804               NaN                      NaN  ...                NaN
# 1805               NaN                      NaN  ...                NaN
# 1807               NaN                      NaN  ...                NaN
#
#       당기순이익(손실)(IFRS)(천원)  재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  \
# 1751                  NaN                NaN             NaN
# 1752                  NaN                NaN             NaN
# 1804                  NaN                NaN             NaN
# 1805                  NaN                NaN             NaN
# 1807                  NaN                NaN             NaN
#
#       매출채권 및 기타유동채권(*)(IFRS)(천원)       상장폐지일  corp_code       corp_name  \
# 1751                         NaN  2025/01/08    1168143  케이만금세기차륜집단유한공사
# 1752                         NaN  2025/01/08    1168143  케이만금세기차륜집단유한공사
# 1804                         NaN  2018/02/13    1010572           패션플랫폼
# 1805                         NaN  2018/02/13    1010572           패션플랫폼
# 1807                         NaN  2015/11/05     599230      평산차업집단유한공사
#
#                                   corp_eng_name  modify_date
# 1751  Cayman Golden Century Wheel Group Limited     20250108
# 1752  Cayman Golden Century Wheel Group Limited     20250108
# 1804                  Fashion Platform Co.,Ltd.     20180213
# 1805                  Fashion Platform Co.,Ltd.     20180213
# 1807                PING SHAN TEA GROUP LIMITED     20170630
#
# [5 rows x 33 columns]

# %%
api_key = os.getenv("DART_API_KEY")  # 본인의 API KEY로 교체
bsns_year = 2018
reprt_code = "11011"
fs_div = "OFS"
corp_code = 1168143  
print(str(corp_code).zfill(8))
url = (
    f"https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json"
    f"?crtfc_key={api_key}"
    f"&corp_code={str(corp_code).zfill(8)}"
    f"&bsns_year={bsns_year}"
    f"&reprt_code={reprt_code}"
    f"&fs_div={fs_div}"
)
response = requests.get(url)
data = response.json()
data
# Out:
# 01168143
# {'status': '013', 'message': '조회된 데이타가 없습니다.'}

# %%
import requests
import pandas as pd
import time
import os

api_key = os.getenv("DART_API_KEY")  # 본인의 API KEY로 교체
bsns_year = 2014
reprt_code = "11011"
fs_div = "OFS"

company_dfs = {}

for corp_code in merged_df['corp_code'].unique():
    code = str(corp_code).zfill(8)
    print(f"{merged_df.loc[merged_df['corp_code'] == corp_code, ['corp_name']]} 받는 중 ...")
    for bsns_year in range(2014,2024):
        url = (
            f"https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json"
            f"?crtfc_key={api_key}"
            f"&corp_code={code}"
            f"&bsns_year={bsns_year}"
            f"&reprt_code={reprt_code}"
            f"&fs_div={fs_div}"
        )
        response = requests.get(url)
        data = response.json()
        if data.get('status') == '000':
            for item in data['list']:
                df = pd.DataFrame(data['list'])
                df['corp_code'] = corp_code
                company_dfs[corp_code] = df
        else:
            print(f"{corp_code}: {data.get('message')}")
        time.sleep(0.2)  # DART API 과다 요청 방지 (0.2초 대기)

# 모든 회사의 데이터를 하나로 합치고 싶다면
all_df = pd.concat(company_dfs.values(), ignore_index=True)
print(all_df.head())
# Out:
#    Unnamed: 0      회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 0          81  (주)가온칩스     399720  2018/12              NaN
# 1          82  (주)가온칩스     399720  2019/12              NaN
#
#    비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 0                 NaN                NaN              NaN               NaN
# 1                 NaN                NaN              NaN               NaN
#
#    이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 0                      NaN  ...                NaN                  NaN
# 1                      NaN  ...                NaN                  NaN
#
#    재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 0                NaN             NaN                         NaN    NaN
# 1                NaN             NaN                         NaN    NaN
#
#    corp_code  corp_name        corp_eng_name  modify_date
# 0    1364747       가온칩스  GAONCHIPS CO., LTD.     20230216
# 1    1364747       가온칩스  GAONCHIPS CO., LTD.     20230216
#
# [2 rows x 33 columns] 받는 중 ...
# 1364747: 조회된 데이타가 없습니다.
# 1364747: 조회된 데이타가 없습니다.
# 1364747: 조회된 데이타가 없습니다.
# 1364747: 조회된 데이타가 없습니다.
# 1364747: 조회된 데이타가 없습니다.
# 1364747: 조회된 데이타가 없습니다.
# 1364747: 조회된 데이타가 없습니다.
# 1364747: 조회된 데이타가 없습니다.
#    Unnamed: 0       회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 2          87  (주)강동씨앤엘     198440  2014/12              NaN
# 3          88  (주)강동씨앤엘     198440  2015/12              NaN
# 4          89  (주)강동씨앤엘     198440  2016/12              NaN
#
#    비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 2                 NaN                NaN              NaN               NaN
# 3                 NaN                NaN              NaN               NaN
# 4                 NaN                NaN              NaN               NaN
#
#    이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 2                      NaN  ...                NaN                  NaN
# 3                      NaN  ...                NaN                  NaN
# 4                      NaN  ...                NaN                  NaN
#
#    재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 2                NaN             NaN                         NaN    NaN
# 3                NaN             NaN                         NaN    NaN
# 4                NaN             NaN                         NaN    NaN
#
#    corp_code  corp_name          corp_eng_name  modify_date
# 2    1032583      강동씨앤엘  KANGDONG C&L co., Ltd     20250327
# 3    1032583      강동씨앤엘  KANGDONG C&L co., Ltd     20250327
# 4    1032583      강동씨앤엘  KANGDONG C&L co., Ltd     20250327
#
# [3 rows x 33 columns] 받는 중 ...
# 1032583: 조회된 데이타가 없습니다.
# 1032583: 조회된 데이타가 없습니다.
# 1032583: 조회된 데이타가 없습니다.
#    Unnamed: 0         회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 5          97  (주)강스템바이오텍     217730  2014/12              NaN
#
#    비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 5                 NaN                NaN              NaN               NaN
#
#    이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 5                      NaN  ...                NaN                  NaN
#
#    재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 5                NaN             NaN                         NaN    NaN
#
#    corp_code  corp_name               corp_eng_name  modify_date
# 5    1025644    강스템바이오텍  KANGSTEM BIOTECH CO., LTD.     20241209
#
# [1 rows x 33 columns] 받는 중 ...
# 1025644: 조회된 데이타가 없습니다.
#    Unnamed: 0       회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 6         238  (주)골프존데카     183410  2014/12              NaN
# 7         239  (주)골프존데카     183410  2015/12              NaN
# 8         240  (주)골프존데카     183410  2016/12              NaN
# 9         241  (주)골프존데카     183410  2017/12              NaN
#
#    비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 6                 NaN                NaN              NaN               NaN
# 7                 NaN                NaN              NaN               NaN
# 8                 NaN                NaN              NaN               NaN
# 9                 NaN                NaN              NaN               NaN
#
#    이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 6                      NaN  ...                NaN                  NaN
# 7                      NaN  ...                NaN                  NaN
# 8                      NaN  ...                NaN                  NaN
# 9                      NaN  ...                NaN                  NaN
#
#    재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)       상장폐지일  \
# 6                NaN             NaN                         NaN  2024/02/22
# 7                NaN             NaN                         NaN  2024/02/22
# 8                NaN             NaN                         NaN  2024/02/22
# 9                NaN             NaN                         NaN  2024/02/22
#
#    corp_code  corp_name          corp_eng_name  modify_date
# 6     764807    골프존클라우드  GolfzonCloud Co.,Ltd.     20250227
# 7     764807    골프존클라우드  GolfzonCloud Co.,Ltd.     20250227
# 8     764807    골프존클라우드  GolfzonCloud Co.,Ltd.     20250227
# 9     764807    골프존클라우드  GolfzonCloud Co.,Ltd.     20250227
#
# [4 rows x 33 columns] 받는 중 ...
# 764807: 조회된 데이타가 없습니다.
# 764807: 조회된 데이타가 없습니다.
# 764807: 조회된 데이타가 없습니다.
# 764807: 조회된 데이타가 없습니다.
# 764807: 조회된 데이타가 없습니다.
# 764807: 조회된 데이타가 없습니다.
# 764807: 조회된 데이타가 없습니다.
# 764807: 조회된 데이타가 없습니다.
# 764807: 조회된 데이타가 없습니다.
# 764807: 조회된 데이타가 없습니다.
#     Unnamed: 0      회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 10         257  (주)공구우먼     366030  2017/12              NaN
# 11         258  (주)공구우먼     366030  2018/12              NaN
# 12         259  (주)공구우먼     366030  2019/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 10                 NaN                NaN              NaN               NaN
# 11                 NaN                NaN              NaN               NaN
# 12                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 10                      NaN  ...                NaN                  NaN
# 11                      NaN  ...                NaN                  NaN
# 12                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 10                NaN             NaN                         NaN    NaN
# 11                NaN             NaN                         NaN    NaN
# 12                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name      corp_eng_name  modify_date
# 10    1307335       공구우먼  09women Co., Ltd.     20240827
# 11    1307335       공구우먼  09women Co., Ltd.     20240827
# 12    1307335       공구우먼  09women Co., Ltd.     20240827
#
# [3 rows x 33 columns] 받는 중 ...
# 1307335: 조회된 데이타가 없습니다.
# 1307335: 조회된 데이타가 없습니다.
# 1307335: 조회된 데이타가 없습니다.
# 1307335: 조회된 데이타가 없습니다.
# 1307335: 조회된 데이타가 없습니다.
# 1307335: 조회된 데이타가 없습니다.
# 1307335: 조회된 데이타가 없습니다.
#     Unnamed: 0      회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 13         304  (주)구스앤홈     329050  2017/12              NaN
# 14         305  (주)구스앤홈     329050  2018/12              NaN
# 15         306  (주)구스앤홈     329050  2019/12              NaN
# 16         307  (주)구스앤홈     329050  2020/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 13                 NaN                NaN              NaN               NaN
# 14                 NaN                NaN              NaN               NaN
# 15                 NaN                NaN              NaN               NaN
# 16                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 13                      NaN  ...                NaN                  NaN
# 14                      NaN  ...                NaN                  NaN
# 15                      NaN  ...                NaN                  NaN
# 16                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)       상장폐지일  \
# 13                NaN             NaN                         NaN  2021/04/13
# 14                NaN             NaN                         NaN  2021/04/13
# 15                NaN             NaN                         NaN  2021/04/13
# 16                NaN             NaN                         NaN  2021/04/13
#
#     corp_code  corp_name          corp_eng_name  modify_date
# 13    1337114       구스앤홈  GOOSE & HOME Co., Ltd     20210413
# 14    1337114       구스앤홈  GOOSE & HOME Co., Ltd     20210413
# 15    1337114       구스앤홈  GOOSE & HOME Co., Ltd     20210413
# 16    1337114       구스앤홈  GOOSE & HOME Co., Ltd     20210413
#
# [4 rows x 33 columns] 받는 중 ...
# 1337114: 조회된 데이타가 없습니다.
# 1337114: 조회된 데이타가 없습니다.
# 1337114: 조회된 데이타가 없습니다.
# 1337114: 조회된 데이타가 없습니다.
# 1337114: 조회된 데이타가 없습니다.
# 1337114: 조회된 데이타가 없습니다.
# 1337114: 조회된 데이타가 없습니다.
# 1337114: 조회된 데이타가 없습니다.
# 1337114: 조회된 데이타가 없습니다.
# 1337114: 조회된 데이타가 없습니다.
#     Unnamed: 0      회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 17         358  (주)국전약품     307750  2018/12              NaN
# 18         359  (주)국전약품     307750  2019/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 17                 NaN                NaN              NaN               NaN
# 18                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 17                      NaN  ...                NaN                  NaN
# 18                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 17                NaN             NaN                         NaN    NaN
# 18                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name                   corp_eng_name  modify_date
# 17    1329957       국전약품  KUKJEON PHARMACEUTICAL Co.,Ltd     20220228
# 18    1329957       국전약품  KUKJEON PHARMACEUTICAL Co.,Ltd     20220228
#
# [2 rows x 33 columns] 받는 중 ...
# 1329957: 조회된 데이타가 없습니다.
# 1329957: 조회된 데이타가 없습니다.
# 1329957: 조회된 데이타가 없습니다.
# 1329957: 조회된 데이타가 없습니다.
# 1329957: 조회된 데이타가 없습니다.
# 1329957: 조회된 데이타가 없습니다.
#     Unnamed: 0       회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 19         374  (주)그리드위즈     453450  2017/12              NaN
# 20         375  (주)그리드위즈     453450  2018/12              NaN
# 21         376  (주)그리드위즈     453450  2019/12              NaN
# 22         377  (주)그리드위즈     453450  2020/12              NaN
# 23         378  (주)그리드위즈     453450  2021/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 19                 NaN                NaN              NaN               NaN
# 20                 NaN                NaN              NaN               NaN
# 21                 NaN                NaN              NaN               NaN
# 22                 NaN                NaN              NaN               NaN
# 23                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 19                      NaN  ...                NaN                  NaN
# 20                      NaN  ...                NaN                  NaN
# 21                      NaN  ...                NaN                  NaN
# 22                      NaN  ...                NaN                  NaN
# 23                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 19                NaN             NaN                         NaN    NaN
# 20                NaN             NaN                         NaN    NaN
# 21                NaN             NaN                         NaN    NaN
# 22                NaN             NaN                         NaN    NaN
# 23                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name    corp_eng_name  modify_date
# 19    1299203      그리드위즈  Gridwiz Co.,Ltd     20240614
# 20    1299203      그리드위즈  Gridwiz Co.,Ltd     20240614
# 21    1299203      그리드위즈  Gridwiz Co.,Ltd     20240614
# 22    1299203      그리드위즈  Gridwiz Co.,Ltd     20240614
# 23    1299203      그리드위즈  Gridwiz Co.,Ltd     20240614
#
# [5 rows x 33 columns] 받는 중 ...
# 1299203: 조회된 데이타가 없습니다.
# 1299203: 조회된 데이타가 없습니다.
# 1299203: 조회된 데이타가 없습니다.
# 1299203: 조회된 데이타가 없습니다.
# 1299203: 조회된 데이타가 없습니다.
# 1299203: 조회된 데이타가 없습니다.
# 1299203: 조회된 데이타가 없습니다.
# 1299203: 조회된 데이타가 없습니다.
# 1299203: 조회된 데이타가 없습니다.
# 1299203: 조회된 데이타가 없습니다.
#     Unnamed: 0       회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 24         391  (주)그린리소스     402490  2018/12              NaN
# 25         392  (주)그린리소스     402490  2019/12              NaN
# 26         393  (주)그린리소스     402490  2020/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 24                 NaN                NaN              NaN               NaN
# 25                 NaN                NaN              NaN               NaN
# 26                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 24                      NaN  ...                NaN                  NaN
# 25                      NaN  ...                NaN                  NaN
# 26                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 24                NaN             NaN                         NaN    NaN
# 25                NaN             NaN                         NaN    NaN
# 26                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name           corp_eng_name  modify_date
# 24    1370863      그린리소스  Green Resource Co.,Ltd     20240430
# 25    1370863      그린리소스  Green Resource Co.,Ltd     20240430
# 26    1370863      그린리소스  Green Resource Co.,Ltd     20240430
#
# [3 rows x 33 columns] 받는 중 ...
# 1370863: 조회된 데이타가 없습니다.
# 1370863: 조회된 데이타가 없습니다.
# 1370863: 조회된 데이타가 없습니다.
# 1370863: 조회된 데이타가 없습니다.
# 1370863: 조회된 데이타가 없습니다.
# 1370863: 조회된 데이타가 없습니다.
# 1370863: 조회된 데이타가 없습니다.
# 1370863: 조회된 데이타가 없습니다.
# 1370863: 조회된 데이타가 없습니다.
#     Unnamed: 0       회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 27         397  (주)그린플러스     186230  2014/12              NaN
# 28         398  (주)그린플러스     186230  2015/12              NaN
# 29         399  (주)그린플러스     186230  2016/12              NaN
# 30         400  (주)그린플러스     186230  2017/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 27                 NaN                NaN              NaN               NaN
# 28                 NaN                NaN              NaN               NaN
# 29                 NaN                NaN              NaN               NaN
# 30                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 27                      NaN  ...                NaN                  NaN
# 28                      NaN  ...                NaN                  NaN
# 29                      NaN  ...                NaN                  NaN
# 30                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 27                NaN             NaN                         NaN    NaN
# 28                NaN             NaN                         NaN    NaN
# 29                NaN             NaN                         NaN    NaN
# 30                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name         corp_eng_name  modify_date
# 27     602279      그린플러스  GREEN PLUS Co., Ltd.     20230328
# 28     602279      그린플러스  GREEN PLUS Co., Ltd.     20230328
# 29     602279      그린플러스  GREEN PLUS Co., Ltd.     20230328
# 30     602279      그린플러스  GREEN PLUS Co., Ltd.     20230328
#
# [4 rows x 33 columns] 받는 중 ...
# 602279: 조회된 데이타가 없습니다.
# 602279: 조회된 데이타가 없습니다.
# 602279: 조회된 데이타가 없습니다.
# 602279: 조회된 데이타가 없습니다.
# 602279: 조회된 데이타가 없습니다.
#     Unnamed: 0       회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 31         407  (주)극동자동화     272420  2014/12              NaN
# 32         408  (주)극동자동화     272420  2015/12              NaN
# 33         409  (주)극동자동화     272420  2016/12              NaN
# 34         410  (주)극동자동화     272420  2017/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 31                 NaN                NaN              NaN               NaN
# 32                 NaN                NaN              NaN               NaN
# 33                 NaN                NaN              NaN               NaN
# 34                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 31                      NaN  ...                NaN                  NaN
# 32                      NaN  ...                NaN                  NaN
# 33                      NaN  ...                NaN                  NaN
# 34                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)       상장폐지일  \
# 31                NaN             NaN                         NaN  2018/11/15
# 32                NaN             NaN                         NaN  2018/11/15
# 33                NaN             NaN                         NaN  2018/11/15
# 34                NaN             NaN                         NaN  2018/11/15
#
#     corp_code  corp_name       corp_eng_name  modify_date
# 31    1088458      극동자동화  Kukdong Automation     20190212
# 32    1088458      극동자동화  Kukdong Automation     20190212
# 33    1088458      극동자동화  Kukdong Automation     20190212
# 34    1088458      극동자동화  Kukdong Automation     20190212
#
# [4 rows x 33 columns] 받는 중 ...
# 1088458: 조회된 데이타가 없습니다.
# 1088458: 조회된 데이타가 없습니다.
# 1088458: 조회된 데이타가 없습니다.
# 1088458: 조회된 데이타가 없습니다.
# 1088458: 조회된 데이타가 없습니다.
# 1088458: 조회된 데이타가 없습니다.
# 1088458: 조회된 데이타가 없습니다.
# 1088458: 조회된 데이타가 없습니다.
# 1088458: 조회된 데이타가 없습니다.
# 1088458: 조회된 데이타가 없습니다.
#     Unnamed: 0       회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 35         438  (주)금오하이텍     165270  2014/12              NaN
# 36         439  (주)금오하이텍     165270  2015/12              NaN
# 37         440  (주)금오하이텍     165270  2016/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 35                 NaN                NaN              NaN               NaN
# 36                 NaN                NaN              NaN               NaN
# 37                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 35                      NaN  ...                NaN                  NaN
# 36                      NaN  ...                NaN                  NaN
# 37                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)       상장폐지일  \
# 35                NaN             NaN                         NaN  2017/06/07
# 36                NaN             NaN                         NaN  2017/06/07
# 37                NaN             NaN                         NaN  2017/06/07
#
#     corp_code  corp_name         corp_eng_name  modify_date
# 35     659815      금오하이텍  KUMO HITEC. CO., LTD     20220225
# 36     659815      금오하이텍  KUMO HITEC. CO., LTD     20220225
# 37     659815      금오하이텍  KUMO HITEC. CO., LTD     20220225
#
# [3 rows x 33 columns] 받는 중 ...
# 659815: 조회된 데이타가 없습니다.
# 659815: 조회된 데이타가 없습니다.
# 659815: 조회된 데이타가 없습니다.
# 659815: 조회된 데이타가 없습니다.
# 659815: 조회된 데이타가 없습니다.
# 659815: 조회된 데이타가 없습니다.
# 659815: 조회된 데이타가 없습니다.
# 659815: 조회된 데이타가 없습니다.
# 659815: 조회된 데이타가 없습니다.
# 659815: 조회된 데이타가 없습니다.
#     Unnamed: 0    회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 38         494  (주)나노     187790  2014/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 38                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 38                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 38                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name    corp_eng_name  modify_date
# 38     994994         나노  NANO. Co., Ltd.     20221128
#
# [1 rows x 33 columns] 받는 중 ...
# 994994: 조회된 데이타가 없습니다.
#     Unnamed: 0           회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 39         514  (주)나노실리칸첨단소재     286750  2015/12              NaN
# 40         515  (주)나노실리칸첨단소재     286750  2016/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 39                 NaN                NaN              NaN               NaN
# 40                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 39                      NaN  ...                NaN                  NaN
# 40                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 39                NaN             NaN                         NaN    NaN
# 40                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name                              corp_eng_name  \
# 39    1136001  나노실리칸첨단소재  NanoSilikhan Advanced Materials Co., Ltd.
# 40    1136001  나노실리칸첨단소재  NanoSilikhan Advanced Materials Co., Ltd.
#
#     modify_date
# 39     20250422
# 40     20250422
#
# [2 rows x 33 columns] 받는 중 ...
# 1136001: 조회된 데이타가 없습니다.
# 1136001: 조회된 데이타가 없습니다.
# 1136001: 조회된 데이타가 없습니다.
# 1136001: 조회된 데이타가 없습니다.
# 1136001: 조회된 데이타가 없습니다.
#     Unnamed: 0       회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 41         533  (주)나래나노텍     137080  2014/12              NaN
# 42         534  (주)나래나노텍     137080  2015/12              NaN
# 43         535  (주)나래나노텍     137080  2016/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 41                 NaN                NaN              NaN               NaN
# 42                 NaN                NaN              NaN               NaN
# 43                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 41                      NaN  ...                NaN                  NaN
# 42                      NaN  ...                NaN                  NaN
# 43                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 41                NaN             NaN                         NaN    NaN
# 42                NaN             NaN                         NaN    NaN
# 43                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name               corp_eng_name  modify_date
# 41     362122      나래나노텍  NARAE NANOTECH CORPORATION     20250514
# 42     362122      나래나노텍  NARAE NANOTECH CORPORATION     20250514
# 43     362122      나래나노텍  NARAE NANOTECH CORPORATION     20250514
#
# [3 rows x 33 columns] 받는 중 ...
# 362122: 조회된 데이타가 없습니다.
# 362122: 조회된 데이타가 없습니다.
# 362122: 조회된 데이타가 없습니다.
# 362122: 조회된 데이타가 없습니다.
# 362122: 조회된 데이타가 없습니다.
# 362122: 조회된 데이타가 없습니다.
# 362122: 조회된 데이타가 없습니다.
#     Unnamed: 0     회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 44         586  (주)나이코     192240  2014/12              NaN
# 45         587  (주)나이코     192240  2015/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 44                 NaN                NaN              NaN               NaN
# 45                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 44                      NaN  ...                NaN                  NaN
# 45                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)       상장폐지일  \
# 44                NaN             NaN                         NaN  2016/12/23
# 45                NaN             NaN                         NaN  2016/12/23
#
#     corp_code  corp_name  corp_eng_name  modify_date
# 44     967778        나이코  NYCO CO.,LTD.     20170630
# 45     967778        나이코  NYCO CO.,LTD.     20170630
#
# [2 rows x 33 columns] 받는 중 ...
# 967778: 조회된 데이타가 없습니다.
# 967778: 조회된 데이타가 없습니다.
# 967778: 조회된 데이타가 없습니다.
# 967778: 조회된 데이타가 없습니다.
# 967778: 조회된 데이타가 없습니다.
# 967778: 조회된 데이타가 없습니다.
# 967778: 조회된 데이타가 없습니다.
# 967778: 조회된 데이타가 없습니다.
# 967778: 조회된 데이타가 없습니다.
# 967778: 조회된 데이타가 없습니다.
#     Unnamed: 0      회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 46         588  (주)나인테크     267320  2017/12              NaN
# 47         589  (주)나인테크     267320  2018/12              NaN
# 48         590  (주)나인테크     267320  2019/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 46                 NaN                NaN              NaN               NaN
# 47                 NaN                NaN              NaN               NaN
# 48                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 46                      NaN  ...                NaN                  NaN
# 47                      NaN  ...                NaN                  NaN
# 48                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 46                NaN             NaN                         NaN    NaN
# 47                NaN             NaN                         NaN    NaN
# 48                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name       corp_eng_name  modify_date
# 46    1208849       나인테크  Naintech. CO.,LTD.     20220622
# 47    1208849       나인테크  Naintech. CO.,LTD.     20220622
# 48    1208849       나인테크  Naintech. CO.,LTD.     20220622
#
# [3 rows x 33 columns] 받는 중 ...
# 1208849: 조회된 데이타가 없습니다.
# 1208849: 조회된 데이타가 없습니다.
# 1208849: 조회된 데이타가 없습니다.
# 1208849: 조회된 데이타가 없습니다.
# 1208849: 조회된 데이타가 없습니다.
# 1208849: 조회된 데이타가 없습니다.
#     Unnamed: 0     회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 49         635  (주)네오셈     253590  2016/12              NaN
# 50         636  (주)네오셈     253590  2017/12              NaN
# 51         637  (주)네오셈     253590  2018/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 49                 NaN                NaN              NaN               NaN
# 50                 NaN                NaN              NaN               NaN
# 51                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 49                      NaN  ...                NaN                  NaN
# 50                      NaN  ...                NaN                  NaN
# 51                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 49                NaN             NaN                         NaN    NaN
# 50                NaN             NaN                         NaN    NaN
# 51                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name  corp_eng_name  modify_date
# 49    1170865        네오셈    Neosem Inc.     20221209
# 50    1170865        네오셈    Neosem Inc.     20221209
# 51    1170865        네오셈    Neosem Inc.     20221209
#
# [3 rows x 33 columns] 받는 중 ...
# 1170865: 조회된 데이타가 없습니다.
# 1170865: 조회된 데이타가 없습니다.
# 1170865: 조회된 데이타가 없습니다.
# 1170865: 조회된 데이타가 없습니다.
#     Unnamed: 0       회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 52         678  (주)네오크레마     311390  2016/12              NaN
# 53         679  (주)네오크레마     311390  2017/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 52                 NaN                NaN              NaN               NaN
# 53                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 52                      NaN  ...                NaN                  NaN
# 53                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 52                NaN             NaN                         NaN    NaN
# 53                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name         corp_eng_name  modify_date
# 52    1219155      네오크레마  Neo Cremar Co., Ltd.     20250617
# 53    1219155      네오크레마  Neo Cremar Co., Ltd.     20250617
#
# [2 rows x 33 columns] 받는 중 ...
# 1219155: 조회된 데이타가 없습니다.
# 1219155: 조회된 데이타가 없습니다.
# 1219155: 조회된 데이타가 없습니다.
# 1219155: 조회된 데이타가 없습니다.
# 1219155: 조회된 데이타가 없습니다.
#     Unnamed: 0      회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 54         713  (주)네온테크     306620  2018/12              NaN
# 55         714  (주)네온테크     306620  2019/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 54                 NaN                NaN              NaN               NaN
# 55                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 54                      NaN  ...                NaN                  NaN
# 55                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 54                NaN             NaN                         NaN    NaN
# 55                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name       corp_eng_name  modify_date
# 54    1325429       네온테크  Neontech Co., Ltd.     20221212
# 55    1325429       네온테크  Neontech Co., Ltd.     20221212
#
# [2 rows x 33 columns] 받는 중 ...
# 1325429: 조회된 데이타가 없습니다.
# 1325429: 조회된 데이타가 없습니다.
# 1325429: 조회된 데이타가 없습니다.
# 1325429: 조회된 데이타가 없습니다.
# 1325429: 조회된 데이타가 없습니다.
#     Unnamed: 0         회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 56         754  (주)넥사다이내믹스     351320  2020/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 56                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 56                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 56                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name            corp_eng_name  modify_date
# 56    1440153    넥사다이내믹스  Nexa Dynamics Co., Ltd.     20250514
#
# [1 rows x 33 columns] 받는 중 ...
# 1440153: 조회된 데이타가 없습니다.
# 1440153: 조회된 데이타가 없습니다.
# 1440153: 조회된 데이타가 없습니다.
# 1440153: 조회된 데이타가 없습니다.
# 1440153: 조회된 데이타가 없습니다.
# 1440153: 조회된 데이타가 없습니다.
# 1440153: 조회된 데이타가 없습니다.
#     Unnamed: 0           회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 57         785  (주)넥스트바이오메디컬     389650  2018/12              NaN
# 58         786  (주)넥스트바이오메디컬     389650  2019/12              NaN
# 59         787  (주)넥스트바이오메디컬     389650  2020/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 57                 NaN                NaN              NaN               NaN
# 58                 NaN                NaN              NaN               NaN
# 59                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 57                      NaN  ...                NaN                  NaN
# 58                      NaN  ...                NaN                  NaN
# 59                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 57                NaN             NaN                         NaN    NaN
# 58                NaN             NaN                         NaN    NaN
# 59                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name             corp_eng_name  modify_date
# 57    1385050  넥스트바이오메디컬  NEXTBIOMEDICAL Co., Ltd.     20240820
# 58    1385050  넥스트바이오메디컬  NEXTBIOMEDICAL Co., Ltd.     20240820
# 59    1385050  넥스트바이오메디컬  NEXTBIOMEDICAL Co., Ltd.     20240820
#
# [3 rows x 33 columns] 받는 중 ...
# 1385050: 조회된 데이타가 없습니다.
# 1385050: 조회된 데이타가 없습니다.
# 1385050: 조회된 데이타가 없습니다.
# 1385050: 조회된 데이타가 없습니다.
# 1385050: 조회된 데이타가 없습니다.
# 1385050: 조회된 데이타가 없습니다.
# 1385050: 조회된 데이타가 없습니다.
# 1385050: 조회된 데이타가 없습니다.
# 1385050: 조회된 데이타가 없습니다.
# 1385050: 조회된 데이타가 없습니다.
#     Unnamed: 0     회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 60         815  (주)넥스틴     348210  2014/12              NaN
# 61         816  (주)넥스틴     348210  2015/12              NaN
# 62         817  (주)넥스틴     348210  2016/12              NaN
# 63         818  (주)넥스틴     348210  2017/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 60                 NaN                NaN              NaN               NaN
# 61                 NaN                NaN              NaN               NaN
# 62                 NaN                NaN              NaN               NaN
# 63                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 60                      NaN  ...                NaN                  NaN
# 61                      NaN  ...                NaN                  NaN
# 62                      NaN  ...                NaN                  NaN
# 63                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 60                NaN             NaN                         NaN    NaN
# 61                NaN             NaN                         NaN    NaN
# 62                NaN             NaN                         NaN    NaN
# 63                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name  corp_eng_name  modify_date
# 60    1080252        넥스틴    NEXTIN Inc.     20231218
# 61    1080252        넥스틴    NEXTIN Inc.     20231218
# 62    1080252        넥스틴    NEXTIN Inc.     20231218
# 63    1080252        넥스틴    NEXTIN Inc.     20231218
#
# [4 rows x 33 columns] 받는 중 ...
# 1080252: 조회된 데이타가 없습니다.
# 1080252: 조회된 데이타가 없습니다.
# 1080252: 조회된 데이타가 없습니다.
# 1080252: 조회된 데이타가 없습니다.
# 1080252: 조회된 데이타가 없습니다.
# 1080252: 조회된 데이타가 없습니다.
#     Unnamed: 0       회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 64         825  (주)넥슨게임즈     225570  2015/12              NaN
# 65         826  (주)넥슨게임즈     225570  2016/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 64                 NaN                NaN              NaN               NaN
# 65                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 64                      NaN  ...                NaN                  NaN
# 65                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 64                NaN             NaN                         NaN    NaN
# 65                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name          corp_eng_name  modify_date
# 64    1096341      넥슨게임즈  NEXON Games Co., Ltd.     20240110
# 65    1096341      넥슨게임즈  NEXON Games Co., Ltd.     20240110
#
# [2 rows x 33 columns] 받는 중 ...
# 1096341: 조회된 데이타가 없습니다.
# 1096341: 조회된 데이타가 없습니다.
# 1096341: 조회된 데이타가 없습니다.
#     Unnamed: 0     회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 66         834  (주)넥써쓰     205500  2014/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 66                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 66                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 66                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name    corp_eng_name  modify_date
# 66    1042429        넥써쓰  NEXUS Co., Ltd.     20250228
#
# [1 rows x 33 columns] 받는 중 ...
# 1042429: 조회된 데이타가 없습니다.
#     Unnamed: 0    회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 67         844  (주)넵튠     217270  2015/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 67                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 67                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 67                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name    corp_eng_name  modify_date
# 67    1067808         넵튠  Neptune Company     20250521
#
# [1 rows x 33 columns] 받는 중 ...
# 1067808: 조회된 데이타가 없습니다.
# 1067808: 조회된 데이타가 없습니다.
#     Unnamed: 0      회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 68         908  (주)노브랜드     145170  2014/12              NaN
# 69         909  (주)노브랜드     145170  2015/12              NaN
# 70         910  (주)노브랜드     145170  2016/12              NaN
# 71         911  (주)노브랜드     145170  2017/12              NaN
# 72         912  (주)노브랜드     145170  2018/12              NaN
# 73         913  (주)노브랜드     145170  2019/12              NaN
# 74         914  (주)노브랜드     145170  2020/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 68                 NaN                NaN              NaN               NaN
# 69                 NaN                NaN              NaN               NaN
# 70                 NaN                NaN              NaN               NaN
# 71                 NaN                NaN              NaN               NaN
# 72                 NaN                NaN              NaN               NaN
# 73                 NaN                NaN              NaN               NaN
# 74                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 68                      NaN  ...                NaN                  NaN
# 69                      NaN  ...                NaN                  NaN
# 70                      NaN  ...                NaN                  NaN
# 71                      NaN  ...                NaN                  NaN
# 72                      NaN  ...                NaN                  NaN
# 73                      NaN  ...                NaN                  NaN
# 74                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 68                NaN             NaN                         NaN    NaN
# 69                NaN             NaN                         NaN    NaN
# 70                NaN             NaN                         NaN    NaN
# 71                NaN             NaN                         NaN    NaN
# 72                NaN             NaN                         NaN    NaN
# 73                NaN             NaN                         NaN    NaN
# 74                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name               corp_eng_name  modify_date
# 68     305941       노브랜드  Nobland International Inc.     20250401
# 69     305941       노브랜드  Nobland International Inc.     20250401
# 70     305941       노브랜드  Nobland International Inc.     20250401
# 71     305941       노브랜드  Nobland International Inc.     20250401
# 72     305941       노브랜드  Nobland International Inc.     20250401
# 73     305941       노브랜드  Nobland International Inc.     20250401
# 74     305941       노브랜드  Nobland International Inc.     20250401
#
# [7 rows x 33 columns] 받는 중 ...
# 305941: 조회된 데이타가 없습니다.
# 305941: 조회된 데이타가 없습니다.
# 305941: 조회된 데이타가 없습니다.
# 305941: 조회된 데이타가 없습니다.
# 305941: 조회된 데이타가 없습니다.
# 305941: 조회된 데이타가 없습니다.
# 305941: 조회된 데이타가 없습니다.
# 305941: 조회된 데이타가 없습니다.
# 305941: 조회된 데이타가 없습니다.
# 305941: 조회된 데이타가 없습니다.
#     Unnamed: 0    회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 75        1023  (주)누보     332290  2019/12              NaN
# 76        1024  (주)누보     332290  2020/12              NaN
# 77        1025  (주)누보     332290  2021/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 75                 NaN                NaN              NaN               NaN
# 76                 NaN                NaN              NaN               NaN
# 77                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 75                      NaN  ...                NaN                  NaN
# 76                      NaN  ...                NaN                  NaN
# 77                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 75                NaN             NaN                         NaN    NaN
# 76                NaN             NaN                         NaN    NaN
# 77                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name    corp_eng_name  modify_date
# 75    1394669         누보  NOUSBO CO., LTD     20230224
# 76    1394669         누보  NOUSBO CO., LTD     20230224
# 77    1394669         누보  NOUSBO CO., LTD     20230224
#
# [3 rows x 33 columns] 받는 중 ...
# 1394669: 조회된 데이타가 없습니다.
# 1394669: 조회된 데이타가 없습니다.
# 1394669: 조회된 데이타가 없습니다.
# 1394669: 조회된 데이타가 없습니다.
# 1394669: 조회된 데이타가 없습니다.
# 1394669: 조회된 데이타가 없습니다.
# 1394669: 조회된 데이타가 없습니다.
#     Unnamed: 0    회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 78        1109  (주)다린     204690  2014/12              NaN
# 79        1110  (주)다린     204690  2015/12              NaN
# 80        1111  (주)다린     204690  2016/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 78                 NaN                NaN              NaN               NaN
# 79                 NaN                NaN              NaN               NaN
# 80                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 78                      NaN  ...                NaN                  NaN
# 79                      NaN  ...                NaN                  NaN
# 80                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)       상장폐지일  \
# 78                NaN             NaN                         NaN  2017/08/02
# 79                NaN             NaN                         NaN  2017/08/02
# 80                NaN             NaN                         NaN  2017/08/02
#
#     corp_code  corp_name   corp_eng_name  modify_date
# 78     410678         다린  DARIN CO.,LTD.     20200228
# 79     410678         다린  DARIN CO.,LTD.     20200228
# 80     410678         다린  DARIN CO.,LTD.     20200228
#
# [3 rows x 33 columns] 받는 중 ...
# 410678: 조회된 데이타가 없습니다.
# 410678: 조회된 데이타가 없습니다.
# 410678: 조회된 데이타가 없습니다.
# 410678: 조회된 데이타가 없습니다.
# 410678: 조회된 데이타가 없습니다.
# 410678: 조회된 데이타가 없습니다.
# 410678: 조회된 데이타가 없습니다.
# 410678: 조회된 데이타가 없습니다.
# 410678: 조회된 데이타가 없습니다.
# 410678: 조회된 데이타가 없습니다.
#     Unnamed: 0      회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 81        1112  (주)다보링크     340360  2019/12              NaN
# 82        1113  (주)다보링크     340360  2020/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 81                 NaN                NaN              NaN               NaN
# 82                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 81                      NaN  ...                NaN                  NaN
# 82                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 81                NaN             NaN                         NaN    NaN
# 82                NaN             NaN                         NaN    NaN
#
#     corp_code  corp_name  corp_eng_name  modify_date
# 81    1416642       다보링크  DAVOLINK Inc.     20250512
# 82    1416642       다보링크  DAVOLINK Inc.     20250512
#
# [2 rows x 33 columns] 받는 중 ...
# 1416642: 조회된 데이타가 없습니다.
# 1416642: 조회된 데이타가 없습니다.
# 1416642: 조회된 데이타가 없습니다.
# 1416642: 조회된 데이타가 없습니다.
# 1416642: 조회된 데이타가 없습니다.
# 1416642: 조회된 데이타가 없습니다.
# 1416642: 조회된 데이타가 없습니다.
#     Unnamed: 0       회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 83        1157  (주)다원넥스뷰     323350  2017/12              NaN
# 84        1158  (주)다원넥스뷰     323350  2018/12              NaN
# 85        1159  (주)다원넥스뷰     323350  2019/12              NaN
# 86        1160  (주)다원넥스뷰     323350  2020/12              NaN
# 87        1161  (주)다원넥스뷰     323350  2021/12              NaN
#
#     비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  자본금(*)(IFRS)(천원)  \
# 83                 NaN                NaN              NaN               NaN
# 84                 NaN                NaN              NaN               NaN
# 85                 NaN                NaN              NaN               NaN
# 86                 NaN                NaN              NaN               NaN
# 87                 NaN                NaN              NaN               NaN
#
#     이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  당기순이익(손실)(IFRS)(천원)  \
# 83                      NaN  ...                NaN                  NaN
# 84                      NaN  ...                NaN                  NaN
# 85                      NaN  ...                NaN                  NaN
# 86                      NaN  ...                NaN                  NaN
# 87                      NaN  ...                NaN                  NaN
#
#     재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  \
# 83                NaN             NaN                         NaN    NaN
# 84                NaN             NaN                         NaN    NaN
# 85                NaN             NaN                         NaN    NaN
# 86                NaN             NaN                         NaN    NaN
# ...
# 2089                  NaN                NaN             NaN
# 2090                  NaN                NaN             NaN
# 2091                  NaN                NaN             NaN
# 2092                  NaN                NaN             NaN
# 2093                  NaN                NaN             NaN
# 2094                  NaN                NaN             NaN
# 2095                  NaN                NaN             NaN
# 2096                  NaN                NaN             NaN
#
#       매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  corp_code  corp_name  \
# 2088                         NaN    NaN     765897     한국피아이엠
# 2089                         NaN    NaN     765897     한국피아이엠
# 2090                         NaN    NaN     765897     한국피아이엠
# 2091                         NaN    NaN     765897     한국피아이엠
# 2092                         NaN    NaN     765897     한국피아이엠
# 2093                         NaN    NaN     765897     한국피아이엠
# 2094                         NaN    NaN     765897     한국피아이엠
# 2095                         NaN    NaN     765897     한국피아이엠
# 2096                         NaN    NaN     765897     한국피아이엠
#
#            corp_eng_name  modify_date
# 2088  PIM KOREA Co.,Ltd.     20250404
# 2089  PIM KOREA Co.,Ltd.     20250404
# 2090  PIM KOREA Co.,Ltd.     20250404
# 2091  PIM KOREA Co.,Ltd.     20250404
# 2092  PIM KOREA Co.,Ltd.     20250404
# 2093  PIM KOREA Co.,Ltd.     20250404
# 2094  PIM KOREA Co.,Ltd.     20250404
# 2095  PIM KOREA Co.,Ltd.     20250404
# 2096  PIM KOREA Co.,Ltd.     20250404
#
# [9 rows x 33 columns] 받는 중 ...
# 765897: 조회된 데이타가 없습니다.
# 765897: 조회된 데이타가 없습니다.
# 765897: 조회된 데이타가 없습니다.
# 765897: 조회된 데이타가 없습니다.
# 765897: 조회된 데이타가 없습니다.
# 765897: 조회된 데이타가 없습니다.
# 765897: 조회된 데이타가 없습니다.
# 765897: 조회된 데이타가 없습니다.
# 765897: 조회된 데이타가 없습니다.
# 765897: 조회된 데이타가 없습니다.
#       Unnamed: 0         회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 2097       23545  한주라이트메탈(주)     198940  2014/12              NaN
# 2098       23546  한주라이트메탈(주)     198940  2015/12              NaN
# 2099       23547  한주라이트메탈(주)     198940  2016/12              NaN
# 2100       23548  한주라이트메탈(주)     198940  2017/12              NaN
# 2101       23549  한주라이트메탈(주)     198940  2018/12              NaN
# 2102       23550  한주라이트메탈(주)     198940  2019/12              NaN
# 2103       23551  한주라이트메탈(주)     198940  2020/12              NaN
#
#       비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  \
# 2097                 NaN                NaN              NaN
# 2098                 NaN                NaN              NaN
# 2099                 NaN                NaN              NaN
# 2100                 NaN                NaN              NaN
# 2101                 NaN                NaN              NaN
# 2102                 NaN                NaN              NaN
# 2103                 NaN                NaN              NaN
#
#       자본금(*)(IFRS)(천원)  이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  \
# 2097               NaN                      NaN  ...                NaN
# 2098               NaN                      NaN  ...                NaN
# 2099               NaN                      NaN  ...                NaN
# 2100               NaN                      NaN  ...                NaN
# 2101               NaN                      NaN  ...                NaN
# 2102               NaN                      NaN  ...                NaN
# 2103               NaN                      NaN  ...                NaN
#
#       당기순이익(손실)(IFRS)(천원)  재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  \
# 2097                  NaN                NaN             NaN
# 2098                  NaN                NaN             NaN
# 2099                  NaN                NaN             NaN
# 2100                  NaN                NaN             NaN
# 2101                  NaN                NaN             NaN
# 2102                  NaN                NaN             NaN
# 2103                  NaN                NaN             NaN
#
#       매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  corp_code  corp_name  \
# 2097                         NaN    NaN     156600    한주라이트메탈
# 2098                         NaN    NaN     156600    한주라이트메탈
# 2099                         NaN    NaN     156600    한주라이트메탈
# 2100                         NaN    NaN     156600    한주라이트메탈
# 2101                         NaN    NaN     156600    한주라이트메탈
# 2102                         NaN    NaN     156600    한주라이트메탈
# 2103                         NaN    NaN     156600    한주라이트메탈
#
#                      corp_eng_name  modify_date
# 2097  HANJOO LIGHT METAL CO., LTD.     20231005
# 2098  HANJOO LIGHT METAL CO., LTD.     20231005
# 2099  HANJOO LIGHT METAL CO., LTD.     20231005
# 2100  HANJOO LIGHT METAL CO., LTD.     20231005
# 2101  HANJOO LIGHT METAL CO., LTD.     20231005
# 2102  HANJOO LIGHT METAL CO., LTD.     20231005
# 2103  HANJOO LIGHT METAL CO., LTD.     20231005
#
# [7 rows x 33 columns] 받는 중 ...
# 156600: 조회된 데이타가 없습니다.
# 156600: 조회된 데이타가 없습니다.
# 156600: 조회된 데이타가 없습니다.
# 156600: 조회된 데이타가 없습니다.
# 156600: 조회된 데이타가 없습니다.
# 156600: 조회된 데이타가 없습니다.
# 156600: 조회된 데이타가 없습니다.
# 156600: 조회된 데이타가 없습니다.
#       Unnamed: 0          회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 2104       23647  해성에어로보틱스(주)     059270  2014/12              NaN
# 2105       23648  해성에어로보틱스(주)     059270  2015/12              NaN
# 2106       23649  해성에어로보틱스(주)     059270  2016/12              NaN
# 2107       23650  해성에어로보틱스(주)     059270  2017/12              NaN
#
#       비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  \
# 2104                 NaN                NaN              NaN
# 2105                 NaN                NaN              NaN
# 2106                 NaN                NaN              NaN
# 2107                 NaN                NaN              NaN
#
#       자본금(*)(IFRS)(천원)  이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  \
# 2104               NaN                      NaN  ...                NaN
# 2105               NaN                      NaN  ...                NaN
# 2106               NaN                      NaN  ...                NaN
# 2107               NaN                      NaN  ...                NaN
#
#       당기순이익(손실)(IFRS)(천원)  재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  \
# 2104                  NaN                NaN             NaN
# 2105                  NaN                NaN             NaN
# 2106                  NaN                NaN             NaN
# 2107                  NaN                NaN             NaN
#
#       매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  corp_code  corp_name  \
# 2104                         NaN    NaN     453442   해성에어로보틱스
# 2105                         NaN    NaN     453442   해성에어로보틱스
# 2106                         NaN    NaN     453442   해성에어로보틱스
# 2107                         NaN    NaN     453442   해성에어로보틱스
#
#                         corp_eng_name  modify_date
# 2104  Haisung Aero-Robotics Co., Ltd.     20240430
# 2105  Haisung Aero-Robotics Co., Ltd.     20240430
# 2106  Haisung Aero-Robotics Co., Ltd.     20240430
# 2107  Haisung Aero-Robotics Co., Ltd.     20240430
#
# [4 rows x 33 columns] 받는 중 ...
# 453442: 조회된 데이타가 없습니다.
# 453442: 조회된 데이타가 없습니다.
# 453442: 조회된 데이타가 없습니다.
# 453442: 조회된 데이타가 없습니다.
# 453442: 조회된 데이타가 없습니다.
# 453442: 조회된 데이타가 없습니다.
# 453442: 조회된 데이타가 없습니다.
#       Unnamed: 0      회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 2108       23687  헝셩그룹(유)     900270  2015/12              NaN
# 2109       23688  헝셩그룹(유)     900270  2016/12              NaN
# 2110       23689  헝셩그룹(유)     900270  2017/12              NaN
# 2111       23690  헝셩그룹(유)     900270  2018/12              NaN
# 2112       23691  헝셩그룹(유)     900270  2019/12              NaN
# 2113       23692  헝셩그룹(유)     900270  2020/12              NaN
# 2114       23693  헝셩그룹(유)     900270  2021/12              NaN
# 2115       23694  헝셩그룹(유)     900270  2022/12              NaN
# 2116       23695  헝셩그룹(유)     900270  2023/12              NaN
#
#       비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  \
# 2108                 NaN                NaN              NaN
# 2109                 NaN                NaN              NaN
# 2110                 NaN                NaN              NaN
# 2111                 NaN                NaN              NaN
# 2112                 NaN                NaN              NaN
# 2113                 NaN                NaN              NaN
# 2114                 NaN                NaN              NaN
# 2115                 NaN                NaN              NaN
# 2116                 NaN                NaN              NaN
#
#       자본금(*)(IFRS)(천원)  이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  \
# 2108               NaN                      NaN  ...                NaN
# 2109               NaN                      NaN  ...                NaN
# 2110               NaN                      NaN  ...                NaN
# 2111               NaN                      NaN  ...                NaN
# 2112               NaN                      NaN  ...                NaN
# 2113               NaN                      NaN  ...                NaN
# 2114               NaN                      NaN  ...                NaN
# 2115               NaN                      NaN  ...                NaN
# 2116               NaN                      NaN  ...                NaN
#
#       당기순이익(손실)(IFRS)(천원)  재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  \
# 2108                  NaN                NaN             NaN
# 2109                  NaN                NaN             NaN
# 2110                  NaN                NaN             NaN
# 2111                  NaN                NaN             NaN
# 2112                  NaN                NaN             NaN
# 2113                  NaN                NaN             NaN
# 2114                  NaN                NaN             NaN
# 2115                  NaN                NaN             NaN
# 2116                  NaN                NaN             NaN
#
#       매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  corp_code  corp_name  \
# 2108                         NaN    NaN    1160512       헝셩그룹
# 2109                         NaN    NaN    1160512       헝셩그룹
# 2110                         NaN    NaN    1160512       헝셩그룹
# 2111                         NaN    NaN    1160512       헝셩그룹
# 2112                         NaN    NaN    1160512       헝셩그룹
# 2113                         NaN    NaN    1160512       헝셩그룹
# 2114                         NaN    NaN    1160512       헝셩그룹
# 2115                         NaN    NaN    1160512       헝셩그룹
# 2116                         NaN    NaN    1160512       헝셩그룹
#
#                                  corp_eng_name  modify_date
# 2108  HENG SHENG HOLDING GROUP COMPANY LIMITED     20221107
# 2109  HENG SHENG HOLDING GROUP COMPANY LIMITED     20221107
# 2110  HENG SHENG HOLDING GROUP COMPANY LIMITED     20221107
# 2111  HENG SHENG HOLDING GROUP COMPANY LIMITED     20221107
# 2112  HENG SHENG HOLDING GROUP COMPANY LIMITED     20221107
# 2113  HENG SHENG HOLDING GROUP COMPANY LIMITED     20221107
# 2114  HENG SHENG HOLDING GROUP COMPANY LIMITED     20221107
# 2115  HENG SHENG HOLDING GROUP COMPANY LIMITED     20221107
# 2116  HENG SHENG HOLDING GROUP COMPANY LIMITED     20221107
#
# [9 rows x 33 columns] 받는 중 ...
# 1160512: 조회된 데이타가 없습니다.
# 1160512: 조회된 데이타가 없습니다.
# 1160512: 조회된 데이타가 없습니다.
# 1160512: 조회된 데이타가 없습니다.
# 1160512: 조회된 데이타가 없습니다.
# 1160512: 조회된 데이타가 없습니다.
# 1160512: 조회된 데이타가 없습니다.
# 1160512: 조회된 데이타가 없습니다.
# 1160512: 조회된 데이타가 없습니다.
# 1160512: 조회된 데이타가 없습니다.
#       Unnamed: 0       회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 2117       23736  현대무벡스(주)     319400  2019/12              NaN
# 2118       23737  현대무벡스(주)     319400  2020/12              NaN
#
#       비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  \
# 2117                 NaN                NaN              NaN
# 2118                 NaN                NaN              NaN
#
#       자본금(*)(IFRS)(천원)  이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  \
# 2117               NaN                      NaN  ...                NaN
# 2118               NaN                      NaN  ...                NaN
#
#       당기순이익(손실)(IFRS)(천원)  재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  \
# 2117                  NaN                NaN             NaN
# 2118                  NaN                NaN             NaN
#
#       매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  corp_code  corp_name  \
# 2117                         NaN    NaN    1358463      현대무벡스
# 2118                         NaN    NaN    1358463      현대무벡스
#
#                 corp_eng_name  modify_date
# 2117  HYUNDAI MOVEX Co., Ltd.     20240329
# 2118  HYUNDAI MOVEX Co., Ltd.     20240329
#
# [2 rows x 33 columns] 받는 중 ...
# 1358463: 조회된 데이타가 없습니다.
# 1358463: 조회된 데이타가 없습니다.
# 1358463: 조회된 데이타가 없습니다.
# 1358463: 조회된 데이타가 없습니다.
# 1358463: 조회된 데이타가 없습니다.
# 1358463: 조회된 데이타가 없습니다.
#       Unnamed: 0      회사명 stock_code     회계년도  자산(*)(IFRS)(천원)  \
# 2119       23990  휴마시스(주)     205470  2014/12              NaN
# 2120       23991  휴마시스(주)     205470  2015/12              NaN
# 2121       23992  휴마시스(주)     205470  2016/12              NaN
#
#       비유동자산(*)(IFRS)(천원)  유동자산(*)(IFRS)(천원)  자본(*)(IFRS)(천원)  \
# 2119                 NaN                NaN              NaN
# 2120                 NaN                NaN              NaN
# 2121                 NaN                NaN              NaN
#
#       자본금(*)(IFRS)(천원)  이익잉여금(결손금)(*)(IFRS)(천원)  ...  매출원가(*)(IFRS)(천원)  \
# 2119               NaN                      NaN  ...                NaN
# 2120               NaN                      NaN  ...                NaN
# 2121               NaN                      NaN  ...                NaN
#
#       당기순이익(손실)(IFRS)(천원)  재고자산(*)(IFRS)(천원)  매출채권(IFRS)(천원)  \
# 2119                  NaN                NaN             NaN
# 2120                  NaN                NaN             NaN
# 2121                  NaN                NaN             NaN
#
#       매출채권 및 기타유동채권(*)(IFRS)(천원)  상장폐지일  corp_code  corp_name  \
# 2119                         NaN    NaN    1042979       휴마시스
# 2120                         NaN    NaN    1042979       휴마시스
# 2121                         NaN    NaN    1042979       휴마시스
#
#           corp_eng_name  modify_date
# 2119  HUMASIS CO., LTD.     20230320
# 2120  HUMASIS CO., LTD.     20230320
# 2121  HUMASIS CO., LTD.     20230320
#
# [3 rows x 33 columns] 받는 중 ...
# 1042979: 조회된 데이타가 없습니다.
# 1042979: 조회된 데이타가 없습니다.
# 1042979: 조회된 데이타가 없습니다.
#          rcept_no reprt_code bsns_year  corp_code sj_div  sj_nm  \
# 0  20240318000834      11011      2023    1364747     BS  재무상태표
# 1  20240318000834      11011      2023    1364747     BS  재무상태표
# 2  20240318000834      11011      2023    1364747     BS  재무상태표
# 3  20240318000834      11011      2023    1364747     BS  재무상태표
# 4  20240318000834      11011      2023    1364747     BS  재무상태표
#
#                          account_id account_nm account_detail thstrm_nm  \
# 0                  ifrs-full_Assets       자산총계              -    제 12 기
# 1           ifrs-full_CurrentAssets       유동자산              -    제 12 기
# 2  ifrs-full_CashAndCashEquivalents   현금및현금성자산              -    제 12 기
# 3   ifrs-full_CurrentContractAssets       계약자산              -    제 12 기
# 4      ifrs-full_OtherCurrentAssets     기타유동자산              -    제 12 기
#
#   thstrm_amount frmtrm_nm frmtrm_amount bfefrmtrm_nm bfefrmtrm_amount ord  \
# 0   94766060365    제 11 기   73187157603       제 10 기      36993114835   7
# 1   64146614854    제 11 기   54576507689       제 10 기      29916404375   8
# 2    6805030432    제 11 기   10587195426       제 10 기       5620688570   9
# 3   12666382358    제 11 기    5814207803       제 10 기       9786662734  10
# 4    3481247840    제 11 기    2527698466       제 10 기        572028190  11
#
#   currency thstrm_add_amount
# 0      KRW               NaN
# 1      KRW               NaN
# 2      KRW               NaN
# 3      KRW               NaN
# 4      KRW               NaN

# %%
import requests
import pandas as pd
import time
import os

api_key = os.getenv("DART_API_KEY")  # 본인의 API KEY로 교체
reprt_code = "11011"
fs_div = "CFS"

company_dfs = {}

for corp_code in null_df['corp_code'].unique():
    for bsns_year in range(2014,2024):
        url = (
            f"https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json"
            f"?crtfc_key={api_key}"
            f"&corp_code={corp_code.strip()}"
            f"&bsns_year={bsns_year}"
            f"&reprt_code={reprt_code}"
            f"&fs_div={fs_div}"
        )
        response = requests.get(url)
        data = response.json()
        if data.get('status') == '000':
            for item in data['list']:
                df = pd.DataFrame(data['list'])
                df['corp_code'] = corp_code
                company_dfs[corp_code] = df
        else:
            print(f"{corp_code}: {data.get('message')}")
        time.sleep(0.2)  # DART API 과다 요청 방지 (0.2초 대기)

# 모든 회사의 데이터를 하나로 합치고 싶다면
all_df2 = pd.concat(company_dfs.values(), ignore_index=True)
print(all_df2.head())
